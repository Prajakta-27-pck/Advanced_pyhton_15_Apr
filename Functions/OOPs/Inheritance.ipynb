# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from dataclasses import dataclass

# %%
class Person:
    def __init__(self,name, age):
        self.name = name
        self.age = age

    def introduce(self):
        print(f'Hi there i am {self.name}')
        print(f'I am {self.age} years Old')

# %%
p1 = Person(name = 'Suresh' ,age = 27)

# %%
p1.name
# Out:
# 'Suresh'

# %%
p1.age
# Out:
# 27

# %%
p1.introduce()
# Out:
# Hi there i am Suresh
# I am 27 years Old

# %%
class Employee(Person):
    def __init__(self, name, age, Company):
        super().__init__(name, age)
        self.Company = Company

    def work(self):
        print(f'I Work At {self.Company}')

# %%
e1 = Employee(name = 'Swara', age = 23, Company ='TCS')

# %%
e1.name
# Out:
# 'Swara'

# %%
e1.age
# Out:
# 23

# %%
e1.Company
# Out:
# 'TCS'

# %%
e1.work()
# Out:
# I Work At TCS

# %%
e1.introduce()
# Out:
# Hi there i am Swara
# I am 23 years Old

# %%
class Employee1(Person):
    def __init__(self, name, age, Company):
        super().__init__(name, age)
        self.Company = Company

    def work(self):
        super().introduce()
        print(f'I Work At {self.Company}')

# %%
e2 = Employee1 (name = 'Prajakta', age = 27, Company = 'IQVIA')

# %%
e2.name
# Out:
# 'Prajakta'

# %%
e2.age
# Out:
# 27

# %%
e2.Company
# Out:
# 'IQVIA'

# %%
e2.introduce()
# Out:
# Hi there i am Prajakta
# I am 27 years Old

# %%
e2.work()
# Out:
# Hi there i am Prajakta
# I am 27 years Old
# I Work At IQVIA

# %%
class Employee1(Person):
    def __init__(self, name, age, Company, salary):
        super().__init__(name, age)
        self.Company = Company
        self.salary = salary

    def work(self):
        super().introduce()
        print(f'I Work At {self.Company}') 

    def salary_hike(self):
        super().introduce()
        
        print('My current Salary is', self.salary, 
              'and after hike is',  round(self.salary*1.10), 'RS')

# %%
e2 = Employee1 (name = 'Prajakta', age = 27, Company = 'IQVIA', salary = 45000)

# %%
e2.salary_hike()
# Out:
# Hi there i am Prajakta
# I am 27 years Old
# My current Salary is 45000 and after hike is 49500 RS

# %%
print(e2)

# %% [markdown]
# ##### Multilevel Inheritance

# %%
class Employee:
    def __init__(self, name : str, emp_id: int):
        self.name = name 
        self.emp_id = emp_id

    def get_employee_info(self):
        print (f"Name is {self.name} and Employee id is {self.emp_id}")
    

class Manager(Employee):
    def __init__(self, name:str, emp_id:int, Department : str):
        super().__init__(name, emp_id)
        self.Department = Department

    def get_manager_info(self):
        super().get_employee_info()
        print (f'Department :{self.Department}')
    
class ProjectManager(Manager):
    def __init__(self, name, emp_id, Department, project):
        super().__init__(name, emp_id, Department)
        self.project = project


    def get_project_manager_info(self):
        super().get_manager_info()
        print (f'Project  : {self.project}')

# %%
e1 = Employee(name = 'Ruta', emp_id = 1234)

# %%
e1.name
# Out:
# 'Ruta'

# %%
e1.emp_id
# Out:
# 1234

# %%
e1.get_employee_info()
# Out:
# Name is Ruta and Employee id is 1234

# %%
m1 = Manager(name = 'Ram', emp_id = 2345, Department = 'HR')

# %%
m1.get_employee_info()
# Out:
# Name is Ram and Employee id is 2345

# %%
m1.get_manager_info()
# Out:
# Name is Ram and Employee id is 2345
# Department :HR

# %%
pm = ProjectManager(name = 'Sara', emp_id = 5678, Department ='IT', project = 'Finance')

# %%
pm.name
# Out:
# 'Sara'

# %%
pm.get_project_manager_info()
# Out:
# Name is Sara and Employee id is 5678
# Department :IT
# Project  : Finance

# %%
pm.get_employee_info()
# Out:
# Name is Sara and Employee id is 5678

# %%
class Employee:
    def __init__(self, name:str ,emp_id : int):
        self.name = name 
        self.emp_id  = emp_id

    def get_employee_info(self):
        return f"Name is {self.name} and Employee id is {self.emp_id}"
    

class Manager(Employee):
    def __init__(self, name:str , emp_id:int , Department: str):
        super().__init__(name ,emp_id)
        self.Department  = Department

    def get_manager_info(self):
        super().get_employee_info()
        return f'{self.get_employee_info()}  , Department : {self.Department} '
    

class ProjectManager(Manager):
    def __init__(self, name , emp_id , Department , Project):
        super().__init__(name , emp_id , Department)
        self.Project =Project

    
    def get_project_manager_info(self):
       
        return f'{self.get_manager_info()},Project : {self.Project}'

# %%
emp1 = Employee(name = 'Rakhi' , emp_id = 7654)

# %%
emp1.get_employee_info()
# Out:
# 'Name is Rakhi and Employee id is 7654'

# %%
manager1  = Manager(name = 'Karan' , emp_id= 9876 , Department= 'Banking')

# %%
manager1.get_employee_info()
# Out:
# 'Name is Karan and Employee id is 9876'

# %%
manager1.get_manager_info()
# Out:
# 'Name is Karan and Employee id is 9876  , Department : Banking '

# %%
pm1 = ProjectManager(name = 'Sanchi' , emp_id = 5678 ,Department= 'IT' , Project ='Finance')

# %%
pm1.Project
# Out:
# 'Finance'

# %%
pm1.get_project_manager_info()
# Out:
# 'Name is Sanchi and Employee id is 5678  , Department : IT ,Project : Finance'

# %%
pm1.get_employee_info()
# Out:
# 'Name is Sanchi and Employee id is 5678'

# %% [markdown]
# #### Hierarchical Inheritance

# %%
from dataclasses import dataclass

# %%
@dataclass
class User:
    name : str
    email : str

    def get_user_info(self):
        print('Name is -->', self.name)
        print('Email is -->', self.email)

class Admin(User):
    def __init__(self, name, email, access :str):
        super().__init__(name, email)
        self.access = access

    def get_admin_info(self):
        super().get_user_info()
        print(f'Access:{self.access}')

class RegularUser(User):
    def __init__(self, name, email,subscription : bool):
        super().__init__(name,email)
        self.subscription = subscription

    def get_RegularUser_info(self):
        super().get_user_info()
        print(f'Subscription :{self.subscription}')

# %%
u1 = User(name = 'Sarthak', email = 'Sarthak@test.com')

# %%
u1.name
# Out:
# 'Sarthak'

# %%
u1.email
# Out:
# 'Sarthak@test.com'

# %%
a1 = Admin(name = 'Shreesha', email= 'shreesha@gmail.com', access= 'Partial')

# %%
print(a1.name)
print(a1.email)
print(a1.access)
# Out:
# Shreesha
# shreesha@gmail.com
# Partial

# %%
a1.get_admin_info()
# Out:
# Name is --> Shreesha
# Email is --> shreesha@gmail.com
# Access:Partial

# %%
a1.get_user_info()
# Out:
# Name is --> Shreesha
# Email is --> shreesha@gmail.com

# %%
ru = RegularUser(name = 'Shreya', email='shreya@gmail.com', subscription= True)

# %%
print(ru.name)
print(ru.email)
print(ru.subscription)
# Out:
# Shreya
# shreya@gmail.com
# True

# %%
ru.get_RegularUser_info()
# Out:
# Name is --> Shreya
# Email is --> shreya@gmail.com
# Subscription :True

# %%
ru.get_user_info()
# Out:
# Name is --> Shreya
# Email is --> shreya@gmail.com

# %%
from dataclasses import dataclass
from pydantic import BaseModel, Field, EmailStr
from datetime import date
from typing import List

# %%
# %pip install pydantic email-validator
# Out:
# ...
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/2.0 MB 1.6 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/2.0 MB 1.6 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.6 MB/s eta 0:00:00
# ...
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
class Student(BaseModel):
    Name : str = Field (description= 'Enter name here')
    Roll_no : int = Field(description='Enter roll_no here', gt = 0)
    Marks : float = Field(description='Enter marks here')
    Email :EmailStr = Field(description= 'Enter email here')
    Doj : date =  Field(description= 'Enter date here')
    Hobbies : List[str] = Field(description='List of Hobbies', default_factory= list)

# %%
s1 = Student(Name = 'Suyash', Roll_no =12, Marks= 78.2, Email='suyash@gmail.com', Doj =date(2020 , 3,3), Hobbies =['swimming'])

# %%
s1.Name
# Out:
# 'Suyash'

# %%
class Student(BaseModel):
    Name : str = Field (description= 'Enter name here')
    Roll_no : int = Field(description='Enter roll_no here', gt = 0)
    Marks : float = Field(description='Enter marks here')
    Email :EmailStr = Field(description= 'Enter email here')
    Doj : date =  Field(description= 'Enter date here')
    Hobbies : List[str] = Field(description='List of Hobbies', default_factory= list)


    def get_Student_info(self):
        print('Name of student -->', self.Name)
        print('Roll_no of student -->', self.Roll_no)
        print('Marks of student -->', self.Marks)
        print('Email of student -->', self.Email)
        print('Doj of student -->', self.Doj)
        print('Hobbies of student are -->', self.Hobbies)

# %%
s1 = Student(Name = 'Suyash', Roll_no =12, Marks= 78.2, Email='suyash@gmail.com', Doj =date(2020 , 3,3), Hobbies =['swimming'])

# %%
s1.get_Student_info()
# Out:
# Name of student --> Suyash
# Roll_no of student --> 12
# Marks of student --> 78.2
# Email of student --> suyash@gmail.com
# Doj of student --> 2020-03-03
# Hobbies of student are --> ['swimming']
